# %% [markdown]
# <a href="https://colab.research.google.com/github/kimjaehwankimjaehwan/deeplearningstudy/blob/main/%EB%AF%B8%EB%8B%88%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B82_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# /content/drive/MyDrive/kdt_2506/data/kpop_idol_followers.csv

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/kdt_2506/data/kpop_idol_followers.csv')
df.head()
# Out:
#   Stage.Name        Group     ig_name  Followers Gender.x  \
# 0        Ace          VAV     ace.vav     335439      Boy
# 1       Ahra     FAVORITE   ahra.view      12342     Girl
# 2    Ahyoung   DAL SHABET   a_young91      10479     Girl
# 3      Alice  HELLO VENUS    hv_alice      11135     Girl
# 4      Amber         F(X)  ajol_llama    5519743     Girl
#
#              Full.Name Korean.Name K.Stage.Name Date.of.Birth       Debut  \
# 0        Jang Wooyoung         장우영          에이스    1992-08-28  2015-10-31
# 1              Go Ahra         고아라           아라    2001-02-21  2017-07-05
# 2          Cho Jayoung         조자영           아영    1991-05-26  2011-01-03
# 3          Song Joohee         송주희          앨리스    1990-03-21  2012-05-09
# 4  Amber Josephine Liu   엠버 조세핀 리우           엠버    1992-09-18  2009-09-05
#
#    ...      Country Second.Country Height  Weight   Birthplace Other.Group  \
# 0  ...  South Korea            NaN  177.0    63.0          NaN         NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Stage.Name      406 non-null    object
#  1   Group           406 non-null    object
#  2   ig_name         406 non-null    object
#  3   Followers       406 non-null    int64
#  4   Gender.x        406 non-null    object
#  5   Full.Name       406 non-null    object
#  6   Korean.Name     406 non-null    object
#  7   K.Stage.Name    406 non-null    object
#  8   Date.of.Birth   406 non-null    object
#  9   Debut           406 non-null    object
#  10  Company         406 non-null    object
#  11  Country         406 non-null    object
#  12  Second.Country  15 non-null     object
#  13  Height          248 non-null    float64
#  14  Weight          175 non-null    float64
#  15  Birthplace      288 non-null    object
#  16  Other.Group     79 non-null     object
# ...

# %%
df.describe()
# Out:
#           Followers      Height      Weight         age  year.career
# count  4.060000e+02  248.000000  175.000000  406.000000   406.000000
# mean   3.638716e+06  170.500000   56.051429   27.559113     8.357143
# std    9.557985e+06    7.594479    8.896770    3.906336     3.471654
# min    7.180000e+02  152.000000   41.000000   16.000000     1.000000
# 25%    8.228275e+04  164.000000   48.000000   25.000000     6.000000
# 50%    5.224690e+05  169.000000   58.000000   27.000000     8.000000
# 75%    3.321642e+06  177.000000   63.000000   30.000000    11.000000
# max    9.333777e+07  187.000000   90.000000   41.000000    17.000000

# %%
df.shape
# Out:
# (406, 21)

# %%
df.columns
# Out:
# Index(['Stage.Name', 'Group', 'ig_name', 'Followers', 'Gender.x', 'Full.Name',
#        'Korean.Name', 'K.Stage.Name', 'Date.of.Birth', 'Debut', 'Company',
#        'Country', 'Second.Country', 'Height', 'Weight', 'Birthplace',
#        'Other.Group', 'Former.Group', 'Gender.y', 'age', 'year.career'],
#       dtype='object')

# %%
df2 = pd.read_csv('/content/drive/MyDrive/kdt_2506/data/K-Pop Details.csv')
df2.head()
# Out:
#   KPOP GROUPS  GENERATION  MEMBERS  DEBUT YEAR FANDOM  NAME     POP SONGS  \
# 0         bts           3        7        2013      A.R.M.Y       Run BTS
# 1   blackpink           3        4        2016        Blink          HYLT
# 2         txt           4        5        2019          Moa  0X1=LoveSong
# 3     enhypen           4        7        2020       Engene    GivenTaken
# 4  stray kids           4        8        2018         Stay       Case143
#
#    DISBANDED  AWARDS  NOMINATIONS  TOTAL  SONGS
# 0        NaN     483        692.0           235
# 1        NaN      85        290.0            58
# 2        NaN      28         85.0            61
# 3        NaN      30         24.0            10
# 4        NaN      40         96.0           105

# %%
df2.shape
# Out:
# (54, 10)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   KPOP GROUPS   54 non-null     object
#  1   GENERATION    54 non-null     int64
#  2   MEMBERS       54 non-null     int64
#  3   DEBUT YEAR    54 non-null     int64
#  4   FANDOM  NAME  52 non-null     object
#  5    POP SONGS    54 non-null     object
#  6   DISBANDED     14 non-null     float64
#  7   AWARDS        54 non-null     int64
#  8   NOMINATIONS   53 non-null     float64
#  9   TOTAL  SONGS  54 non-null     int64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 4.3+ KB

# %%
df2.describe()
# Out:
#        GENERATION    MEMBERS   DEBUT YEAR    DISBANDED      AWARDS  \
# count   54.000000  54.000000    54.000000    14.000000   54.000000
# mean     2.851852   6.796296  2013.018519  2016.642857   49.796296
# std      0.762504   3.455265     6.406043     6.380344   72.570169
# min      1.000000   2.000000  1991.000000  1996.000000    2.000000
# 25%      2.000000   4.250000  2009.000000  2016.250000   13.000000
# 50%      3.000000   6.000000  2015.000000  2017.000000   31.000000
# 75%      3.000000   8.000000  2017.750000  2020.250000   57.500000
# max      4.000000  23.000000  2022.000000  2022.000000  483.000000
#
#        NOMINATIONS  TOTAL  SONGS
# count    53.000000     54.000000
# mean    110.132075     66.518519
# std     117.485030     49.149652
# min       3.000000      4.000000
# 25%      24.000000     25.000000
# 50%      82.000000     58.000000
# 75%     160.000000     95.750000
# max     692.000000    235.000000

# %%
df['Group'].unique()
# Out:
# array(['VAV', 'FAVORITE', 'DAL SHABET', 'HELLO VENUS', 'F(X)',
#        'PINK FANTASY', 'TAHITI', 'OH MY GIRL', "NU'EST", "LADIES' CODE",
#        'BLOCK B', 'LOVELYZ', 'EXO', 'GOT7', 'B.I.G', 'KARD', 'IKON',
#        'APINK', 'WJSN', 'CHERRY BULLET', 'VICTON', 'NATURE', 'ALICE',
#        'LE SSERAFIM', 'IZ*ONE', 'FROMIS_9', 'TWICE', 'A.C.E', 'BTOB',
#        '24K', 'AOA', '2PM', 'FANATICS', 'CRAYON POP', 'LOONA', 'B1A4',
#        'SONAMOO', 'B.A.P', '2EYES', 'HI-L', 'DREAMCATCHER', 'SF9',
#        'SEVENTEEN', 'SUPER JUNIOR', 'BOYFRIEND', 'INFINITE', 'HIGHLIGHT',
#        'DAY6', 'WEKI MEKI', 'NCT', 'AFTER SCHOOL', 'CLC', 'DIA', 'VIVIZ',
#        'BRAVE GIRLS', 'T-ARA', 'ASTRO', 'HINAPIA', 'BROWN EYED GIRLS',
#        'BERRY GOOD', 'GUGUDAN', 'LABOUM', '3YE', 'OMEGA X', 'EXID',
#        'PENTAGON', 'MAMAMOO', 'N.FLYING', 'MOMOLAND', '9MUSES',
#        "GIRL'S DAY", 'BESTIE', 'VIXX', '100%', 'MONSTA X', 'UNI.T',
# ...

# %%
df2['KPOP GROUPS'].unique()
# Out:
# array(['bts', 'blackpink', 'txt', 'enhypen', 'stray kids', 'iz*one',
#        'itzy', 'twice', '(g)-idle', 'aespa', 'winner', 'seventeen', 'exo',
#        'bigbang', 'redvelvet', 'super junior', 'got7', 'treasure',
#        'apink', "girls' gen", 'monstax', 'mamamoo', 'shinee',
#        'wonder girls', 'shinhwa', 'nct', 'block b', 'nct127', 'loona',
#        'tvxq', '2ne1', 'dreamcatcher', 'kard', '4minute', 'the boyz',
#        't-ara', 'kara', 'ikon', 'superm', 'i.o.i', 's.e.s', 'miss a',
#        'april', 'after school', 'clc', 'aoa', 'highlight',
#        'seo taiji&theboys', 'lesserafim', 'new jeans', 'ateez', 'ive',
#        'pentagon', 'purple kiss'], dtype=object)

# %%
df2['KPOP GROUPS'] = df2['KPOP GROUPS'].str.upper()

# %%
df2['KPOP GROUPS'].unique()
# Out:
# array(['BTS', 'BLACKPINK', 'TXT', 'ENHYPEN', 'STRAY KIDS', 'IZ*ONE',
#        'ITZY', 'TWICE', '(G)-IDLE', 'AESPA', 'WINNER', 'SEVENTEEN', 'EXO',
#        'BIGBANG', 'REDVELVET', 'SUPER JUNIOR', 'GOT7', 'TREASURE',
#        'APINK', "GIRLS' GEN", 'MONSTAX', 'MAMAMOO', 'SHINEE',
#        'WONDER GIRLS', 'SHINHWA', 'NCT', 'BLOCK B', 'NCT127', 'LOONA',
#        'TVXQ', '2NE1', 'DREAMCATCHER', 'KARD', '4MINUTE', 'THE BOYZ',
#        'T-ARA', 'KARA', 'IKON', 'SUPERM', 'I.O.I', 'S.E.S', 'MISS A',
#        'APRIL', 'AFTER SCHOOL', 'CLC', 'AOA', 'HIGHLIGHT',
#        'SEO TAIJI&THEBOYS', 'LESSERAFIM', 'NEW JEANS', 'ATEEZ', 'IVE',
#        'PENTAGON', 'PURPLE KISS'], dtype=object)

# %%
merged = pd.merge(df, df2, left_on='Group', right_on='KPOP GROUPS', how='outer')

# %%
merged
# Out:
#     Stage.Name     Group        ig_name  Followers Gender.x         Full.Name  \
# 0          NaN       NaN            NaN        NaN      NaN               NaN
# 1       Minnie  (G)I-DLE      min.nicha  5615380.0     Girl  Nicha Yontararak
# 2       Miyeon  (G)I-DLE     noodle.zip  3582981.0     Girl         Jo Miyeon
# 3       Shuhua  (G)I-DLE      yeh.shaa_  3633778.0     Girl        Yeh Shuhua
# 4       Soyeon  (G)I-DLE  tiny.pretty.j  3826310.0     Girl       Jeon Soyeon
# ..         ...       ...            ...        ...      ...               ...
# 428      Seola      WJSN        seola_s   761738.0     Girl      Kim Hyunjung
# 429     Soobin      WJSN      soobly_s2   252157.0     Girl       Park Soobin
# 430   Yeonjung      WJSN          uyj_s   614951.0     Girl       Yu Yeonjung
# 431    Yeoreum      WJSN      s_ummer_e   340828.0     Girl       Lee Jinsook
# 432        NaN       NaN            NaN        NaN      NaN               NaN
#
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 433 entries, 0 to 432
# Data columns (total 31 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Stage.Name      406 non-null    object
#  1   Group           406 non-null    object
#  2   ig_name         406 non-null    object
#  3   Followers       406 non-null    float64
#  4   Gender.x        406 non-null    object
#  5   Full.Name       406 non-null    object
#  6   Korean.Name     406 non-null    object
#  7   K.Stage.Name    406 non-null    object
#  8   Date.of.Birth   406 non-null    object
#  9   Debut           406 non-null    object
#  10  Company         406 non-null    object
#  11  Country         406 non-null    object
#  12  Second.Country  15 non-null     object
#  13  Height          248 non-null    float64
#  14  Weight          175 non-null    float64
#  15  Birthplace      288 non-null    object
#  16  Other.Group     79 non-null     object
# ...

# %%
merged.describe()
# Out:
#           Followers      Height      Weight         age  year.career  \
# count  4.060000e+02  248.000000  175.000000  406.000000   406.000000
# mean   3.638716e+06  170.500000   56.051429   27.559113     8.357143
# std    9.557985e+06    7.594479    8.896770    3.906336     3.471654
# min    7.180000e+02  152.000000   41.000000   16.000000     1.000000
# 25%    8.228275e+04  164.000000   48.000000   25.000000     6.000000
# 50%    5.224690e+05  169.000000   58.000000   27.000000     8.000000
# 75%    3.321642e+06  177.000000   63.000000   30.000000    11.000000
# max    9.333777e+07  187.000000   90.000000   41.000000    17.000000
#
#        GENERATION     MEMBERS   DEBUT YEAR    DISBANDED      AWARDS  \
# count  164.000000  164.000000   164.000000    32.000000  164.000000
# mean     2.829268    8.695122  2013.054878  2018.062500   65.414634
# std      0.549509    4.996168     4.703807     4.696859   88.315726
# min      1.000000    2.000000  1991.000000  1996.000000    2.000000
# ...

# %%
merged.shape
# Out:
# (433, 31)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# 1. 문자형 컬럼 선택 및 인코딩
merged_cat = merged.select_dtypes(include=['object'])
merged_cat = merged_cat.fillna('Missing')
merged_cat_encoded = pd.get_dummies(merged_cat)

# 2. 수치형 컬럼 선택 및 결측치 처리
merged_num = merged.select_dtypes(exclude=['object'])
num_imputer = SimpleImputer(strategy='mean')
merged_num_imputed = pd.DataFrame(num_imputer.fit_transform(merged_num), columns=merged_num.columns)

# 3. 수치형 정규화
scaler = StandardScaler()
merged_num_scaled = pd.DataFrame(scaler.fit_transform(merged_num_imputed), columns=merged_num.columns)

# 4. 결합
df_final = pd.concat([merged_num_scaled, merged_cat_encoded], axis=1)

# %%
merged_num_imputed
# Out:
#         Followers  Height     Weight        age  year.career  GENERATION  \
# 0    3.638716e+06   170.5  56.051429  27.559113     8.357143    3.000000
# 1    5.615380e+06   170.5  56.051429  25.000000     5.000000    2.829268
# 2    3.582981e+06   170.5  56.051429  26.000000     5.000000    2.829268
# 3    3.633778e+06   161.0  45.000000  23.000000     5.000000    2.829268
# 4    3.826310e+06   157.0  42.000000  24.000000     5.000000    2.829268
# ..            ...     ...        ...        ...          ...         ...
# 428  7.617380e+05   165.0  56.051429  28.000000     7.000000    2.829268
# 429  2.521570e+05   159.0  56.051429  26.000000     7.000000    2.829268
# 430  6.149510e+05   167.0  52.000000  23.000000     7.000000    2.829268
# 431  3.408280e+05   161.0  56.051429  24.000000     7.000000    2.829268
# 432  3.638716e+06   170.5  56.051429  27.559113     8.357143    2.000000
#
#       MEMBERS   DEBUT YEAR  DISBANDED     AWARDS  NOMINATIONS  TOTAL  SONGS
# ...

# %%
df_final.head()
# Out:
#       Followers    Height    Weight       age   year.career  GENERATION  \
# 0  5.037560e-17  0.000000  0.000000  0.000000 -5.290665e-16    0.506395
# 1  2.138370e-01  0.000000  0.000000 -0.677386 -9.998845e-01    0.000000
# 2 -6.029481e-03  0.000000  0.000000 -0.412691 -9.998845e-01    0.000000
# 3 -5.342223e-04 -1.656232 -1.959546 -1.206778 -9.998845e-01    0.000000
# 4  2.029404e-02 -2.353592 -2.491480 -0.942082 -9.998845e-01    0.000000
#
#         MEMBERS  DEBUT YEAR  DISBANDED        AWARDS  ...   POP SONGS_Shock  \
# 0 -1.205430e+00    1.713474        0.0 -5.612996e-01  ...             False
# 1  5.794865e-16    0.000000        0.0  2.622601e-16  ...             False
# 2  5.794865e-16    0.000000        0.0  2.622601e-16  ...             False
# 3  5.794865e-16    0.000000        0.0  2.622601e-16  ...             False
# 4  5.794865e-16    0.000000        0.0  2.622601e-16  ...             False
#
#     POP SONGS_T.O.P   POP SONGS_Talk that Talk   POP SONGS_The Stealer  \
# ...

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 433 entries, 0 to 432
# Columns: 2922 entries, Followers to  POP SONGS_miniskirt
# dtypes: bool(2910), float64(12)
# memory usage: 1.2 MB

# %%
df_final.describe()
# Out:
#           Followers      Height        Weight           age   year.career  \
# count  4.330000e+02  433.000000  4.330000e+02  4.330000e+02  4.330000e+02
# mean   1.230732e-17    0.000000 -1.394830e-16 -3.035806e-16 -6.728003e-16
# std    1.001157e+00    1.001157  1.001157e+00  1.001157e+00  1.001157e+00
# min   -3.935615e-01   -3.225293 -2.668792e+00 -3.059647e+00 -2.191236e+00
# 25%   -3.838314e-01   -0.610191  0.000000e+00 -6.773862e-01 -7.020466e-01
# 50%   -3.217971e-01    0.000000  0.000000e+00  0.000000e+00 -1.063707e-01
# 75%    5.037560e-17    0.087170  0.000000e+00  6.460922e-01  7.871431e-01
# max    9.703713e+00    2.876613  6.019473e+00  3.557745e+00  2.574171e+00
#
#          GENERATION       MEMBERS    DEBUT YEAR   DISBANDED        AWARDS  \
# count  4.330000e+02  4.330000e+02  4.330000e+02  433.000000  4.330000e+02
# mean   1.476879e-16  5.743417e-16  6.541342e-15    0.000000  2.133269e-16
# std    1.001157e+00  1.001157e+00  1.001157e+00    1.001157  1.001157e+00
# ...

# %%
df_final.shape
# Out:
# (433, 2922)

# %%
df_final.columns
# Out:
# Index(['Followers', 'Height', 'Weight', 'age', 'year.career', 'GENERATION',
#        'MEMBERS', 'DEBUT YEAR', 'DISBANDED', 'AWARDS',
#        ...
#        ' POP SONGS_Shock', ' POP SONGS_T.O.P', ' POP SONGS_Talk that Talk',
#        ' POP SONGS_The Stealer', ' POP SONGS_Tomboy',
#        ' POP SONGS_Very Very Very', ' POP SONGS_Wannabe', ' POP SONGS_Wave',
#        ' POP SONGS_Zombie', ' POP SONGS_miniskirt'],
#       dtype='object', length=2922)

# %%
len(df_final.columns)
# Out:
# 2922

# %%
df_final.isnull().sum()
# Out:
# Followers                    0
# Height                       0
# Weight                       0
# age                          0
# year.career                  0
#                             ..
#  POP SONGS_Very Very Very    0
#  POP SONGS_Wannabe           0
#  POP SONGS_Wave              0
#  POP SONGS_Zombie            0
#  POP SONGS_miniskirt         0
# Length: 2922, dtype: int64

# %%
df_final['Followers']
# Out:
# 0      5.037560e-17
# 1      2.138370e-01
# 2     -6.029481e-03
# 3     -5.342223e-04
# 4      2.029404e-02
#            ...
# 428   -3.112338e-01
# 429   -3.663606e-01
# 430   -3.271133e-01
# 431   -3.567681e-01
# 432    5.037560e-17
# Name: Followers, Length: 433, dtype: float64

# %%
y_column_name = 'Followers'
X = df_final.drop(y_column_name, axis=1)
y = df_final[y_column_name]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

model = RandomForestRegressor()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model.fit(X_train, y_train)

train_pred = model.predict(X_train)
test_pred = model.predict(X_test)
print(f"R2(Train / Test) : {r2_score(y_train, train_pred):.4f} / {r2_score(y_test, test_pred):.4f}")
print(f"RMSE(Train / Test) : {mean_squared_error(y_train, train_pred)**0.5:,.0f} / {mean_squared_error(y_test, test_pred)**0.5:,.0f}")
# Out:
# R2(Train / Test) : 0.9649 / 0.8696
# RMSE(Train / Test) : 0 / 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,6))
sns.scatterplot(x=y_test, y=test_pred, alpha=0.7)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')  # reference line
plt.xlabel("Actual Values (y_test)")
plt.ylabel("Predicted Values (test_pred)")
plt.title("Actual vs Predicted")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
residuals = y_test - test_pred

plt.figure(figsize=(6,4))
sns.histplot(residuals, bins=30, kde=True)
plt.title("Residual Distribution")
plt.xlabel("Residuals (Actual - Predicted)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# 모델 훈련 이후
importances = model.feature_importances_
features = X_train.columns

# 중요도를 데이터프레임으로 정리
feat_importances = pd.Series(importances, index=features)

# 상위 20개 피처 시각화 (내림차순 정렬)
plt.figure(figsize=(10, 6))
sns.barplot(x=feat_importances.nlargest(20), y=feat_importances.nlargest(20).index)
plt.title("Top 20 Feature Importances (Random Forest)")
plt.xlabel("Importance Score")
plt.ylabel("Features")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-34-3879197835>:15: UserWarning: Glyph 49240 (\N{HANGUL SYLLABLE BBEU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-34-3879197835>:15: UserWarning: Glyph 46976 (\N{HANGUL SYLLABLE RAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-34-3879197835>:15: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-34-3879197835>:15: UserWarning: Glyph 50556 (\N{HANGUL SYLLABLE YA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-34-3879197835>:15: UserWarning: Glyph 47560 (\N{HANGUL SYLLABLE MA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-34-3879197835>:15: UserWarning: Glyph 45432 (\N{HANGUL SYLLABLE NO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-34-3879197835>:15: UserWarning: Glyph 48152 (\N{HANGUL SYLLABLE BAN}) missing from font(s) DejaVu Sans.
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# 모델의 구조를 설정합니다.
model = Sequential()
model.add(Dense(10, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(30, activation='relu'))
model.add(Dense(40, activation='relu'))
model.add(Dense(1))
model.summary()

# 모델을 실행합니다.
model.compile(optimizer ='adam', loss = 'mean_squared_error')

# 100회 이상 결과가 향상되지 않으면 자동으로 중단되게끔 합니다.
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=100)

# 모델의 이름을 정합니다.
modelpath="/content/drive/MyDrive/kdt_2506/모두의딥러닝/data/miniproject2-3.keras"

# 최적화 모델을 업데이트하고 저장합니다.
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=0, save_best_only=True)

# 실행 관련 설정을 하는 부분입니다. 전체의 20%를 검증셋으로 설정합니다.
history = model.fit(X_train, y_train, validation_split=0.25, epochs=2000, batch_size=32, callbacks=[early_stopping_callback, checkpointer])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 10)             │        29,220 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 30)             │           330 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 40)             │         1,240 │
# ...

# %%
from sklearn.metrics import r2_score

# 학습 후 평가
y_pred = model.predict(X_test)
r2 = r2_score(y_test, y_pred)
print("R² score:", r2)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step
# R² score: 0.8302620170119586

# %%
merged_num_imputed[merged_num_imputed['Followers'] < 0]
# Out:
# Empty DataFrame
# Columns: [Followers, Height, Weight, age, year.career, GENERATION, MEMBERS, DEBUT YEAR, DISBANDED, AWARDS, NOMINATIONS, TOTAL  SONGS]
# Index: []

# %%
means = merged_num_imputed['Followers'].mean()
stds = merged_num_imputed['Followers'].std()

# %%
means
# Out:
# np.float64(3638716.2364532016)

# %%
stds
# Out:
# 9254478.770312453

# %%
# 예측 값과 실제 값, 실행 번호가 들어갈 빈 리스트를 만듭니다.
real_prices =[]
pred_prices = []
X_num = []

# 25개의 샘플을 뽑아 실제 값, 예측 값을 출력해 봅니다.
n_iter = 0
Y_prediction = model.predict(X_test).flatten()
for i in range(25):
    real = y_test.iloc[i]*stds + means
    prediction = Y_prediction[i]*stds + means
    print("실제팔로워: {:.2f}, 예상팔로워: {:.2f}".format(real, prediction))
    real_prices.append(real)
    pred_prices.append(prediction)
    n_iter = n_iter + 1
    X_num.append(n_iter)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 실제팔로워: 50603.29, 예상팔로워: 2023469.99
# 실제팔로워: 5897499.80, 예상팔로워: 8610705.74
# 실제팔로워: 333697.37, 예상팔로워: 1062554.49
# 실제팔로워: 51843.72, 예상팔로워: 2013488.36
# 실제팔로워: 145567.01, 예상팔로워: 1168052.99
# 실제팔로워: 8170445.97, 예상팔로워: 7943323.74
# 실제팔로워: 6696473.94, 예상팔로워: 11141791.74
# 실제팔로워: 3638716.24, 예상팔로워: 3327384.89
# 실제팔로워: 6975.88, 예상팔로워: 5875879.74
# 실제팔로워: 723282.50, 예상팔로워: 1653314.61
# 실제팔로워: 3638716.24, 예상팔로워: 3571680.41
# 실제팔로워: 201928.13, 예상팔로워: 1818384.49
# 실제팔로워: 82530.18, 예상팔로워: 2991000.61
# 실제팔로워: 312170.50, 예상팔로워: 1749075.49
# 실제팔로워: 32049727.14, 예상팔로워: 11050334.24
# 실제팔로워: 127317.92, 예상팔로워: 1477045.74
# 실제팔로워: 3826527.00, 예상팔로워: 4538006.74
# 실제팔로워: 3242002.64, 예상팔로워: 6859868.74
# 실제팔로워: 2046468.31, 예상팔로워: 4155800.99
# 실제팔로워: 14263961.43, 예상팔로워: 18661767.24
# 실제팔로워: 5617666.48, 예상팔로워: 4251010.80
# 실제팔로워: 1843873.24, 예상팔로워: 1628994.61
# 실제팔로워: 208470.69, 예상팔로워: 1129760.49
# 실제팔로워: 3638716.24, 예상팔로워: 2778441.55
# ...

# %%
merged_num_imputed['Followers']
# Out:
# 0      3.638716e+06
# 1      5.615380e+06
# 2      3.582981e+06
# 3      3.633778e+06
# 4      3.826310e+06
#            ...
# 428    7.617380e+05
# 429    2.521570e+05
# 430    6.149510e+05
# 431    3.408280e+05
# 432    3.638716e+06
# Name: Followers, Length: 433, dtype: float64

# %%
real_prices, pred_prices
# Out:
# ([np.float64(50603.28752500098),
#   np.float64(5897499.80279679),
#   np.float64(333697.374968071),
#   np.float64(51843.7207238609),
#   np.float64(145567.00878782477),
#   np.float64(8170445.969088298),
#   np.float64(6696473.939022126),
#   np.float64(3638716.236453202),
#   np.float64(6975.880336373113),
#   np.float64(723282.5023597367),
#   np.float64(3638716.236453202),
#   np.float64(201928.12853197847),
#   np.float64(82530.17591211665),
#   np.float64(312170.5027793045),
#   np.float64(32049727.135628544),
#   np.float64(127317.92376053333),
#   np.float64(3826526.9969071867),
#   np.float64(3242002.636357515),
#   np.float64(2046468.313744182),
#   np.float64(14263961.428353556),
#   np.float64(5617666.482850643),
#   np.float64(1843873.2350077415),
#   np.float64(208470.68781732814),
#   np.float64(3638716.236453202),
#   np.float64(62806.387009182945)],
#  [np.float64(2023469.9864532016),
#   np.float64(8610705.736453202),
#   np.float64(1062554.4864532016),
# ...

# %%
merged_num_imputed['Followers'].mean()
# Out:
# np.float64(3638716.2364532016)

# %%
min(merged_num_imputed['Followers'])
# Out:
# 718.0

# %%
# 그래프를 통해 샘플로 뽑은 25개의 값을 비교해 봅니다.

plt.plot(X_num, pred_prices, label='predicted followers')
plt.plot(X_num, real_prices, label='real followers')
plt.legend()
plt.show()
