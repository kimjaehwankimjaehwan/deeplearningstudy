# %% [markdown]
# <a href="https://colab.research.google.com/github/kimjaehwankimjaehwan/deeplearningstudy/blob/main/EDA%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
score = [21, 78, 89, 57, 75, 99, 98, 87, 70, 65, 88, 95, 94, 55, 93, 83, 78, 62, 65, 77, 80]
plt.hist(score)
plt.show()

# %%
plt.hist(score, bins=5)
plt.show()

# %%
plt.hist(score, cumulative=True)
plt.show()

# %%
plt.hist(score, histtype='step')
# 'bar', 'barstacked', 'step', 'stepfilled'
plt.show()

# %%
data1 = np.random.normal(0, 1, 1000)
data2 = np.random.normal(1, 1, 1000)
# mean, std, count

fig, axs = plt.subplots(2, 2, figsize=(10, 5))

axs[0, 0].hist([data1, data2], bins=30, color=['red', 'blue'], histtype='bar')
axs[0, 0].set_title('Bar')

axs[0, 1].hist([data1, data2], bins=30, color=['red', 'blue'], histtype='barstacked')
axs[0, 1].set_title('Barstacked')

axs[1, 0].hist([data1, data2], bins=30, color=['red', 'blue'], histtype='step')
axs[1, 0].set_title('Step')

axs[1, 1].hist([data1, data2], bins=30, color=['red', 'blue'], histtype='stepfilled')
axs[1, 1].set_title('Stepfilled')

fig.subplots_adjust(hspace=0.5)
plt.show()

# %%
b = [0.25, 0.1, 0.3, 0.35]
a = ['A', 'B', 'C', 'D']
plt.pie(b, labels=a)
plt.show()

# %%
plt.pie(b, labels=a, autopct='%.1f%%')
plt.show()

# %%
cmap = plt.get_cmap('tab20c')
colors = cmap(np.arange(len(b)) % cmap.N)
# colors = ['blue', 'green', 'cyan', 'orange']

explode = (0.2, 0, 0, 0.1)

plt.pie(b, labels=a, autopct='%.1f%%', startangle=90, counterclock=0, colors=colors, explode=explode)
plt.show()

# %%
cmap = plt.get_cmap('tab20c')
colors = cmap(np.arange(len(a)) % cmap.N)

# %%
fig, ax = plt.subplots()
bp = ax.boxplot(score, whis=1.5, vert=True, patch_artist=True)

# Get the whisker values
whiskers = [whisker.get_ydata()[1] for whisker in bp['whiskers']]
print("Lower whisker value:", whiskers[0])
print("Upper whisker value:", whiskers[1])

plt.show()
# Out:
# Lower whisker value: 55.0
# Upper whisker value: 99.0

# %%
score
# Out:
# [21,
#  78,
#  89,
#  57,
#  75,
#  99,
#  98,
#  87,
#  70,
#  65,
#  88,
#  95,
#  94,
#  55,
#  93,
#  83,
#  78,
#  62,
#  65,
#  77,
#  80]

# %%
plt.boxplot(score, vert=False)
plt.show()

# %%
bp = plt.boxplot(score, vert=False, patch_artist=True)
for box in bp['boxes']:
    box.set(color='blue', linewidth=5)
    box.set(facecolor = 'black')
for cap in bp['caps']:
    cap.set(color='red', linewidth=4)
for whisker in bp['whiskers']:
    whisker.set(color='orange', linewidth=2)
for median in bp['medians']:
    median.set(color='cyan', linewidth=2)
for flier in bp['fliers']:
    flier.set(marker='s', markerfacecolor='b', markersize=10, markeredgecolor='r')

plt.show()

# %%
plt.boxplot([data1, data2])
plt.show()

# %%
c = ['apple', 'blueberry', 'cherry', 'orange']
d = [40, 100, 30, 55]
plt.bar(c, d)
plt.show()

# %%
e = ['red', 'blue', 'darkred', 'orange']
plt.bar(c, d, color=e)
plt.show()

# %%
counts2 = [20, 80, 20, 60]
colors2 = ['tomato', 'cornflowerblue', 'indianred', 'gold']

ind = np.arange(len(d))
width = 0.4

plt.bar(ind, d, width, color=e)
# plt.bar(x=ind, height=counts, width=width, color=colors)
plt.bar(ind + width, counts2, width, color=colors2)

plt.xticks(ind + width / 2, c)
plt.show()

# %%
ind
# Out:
# array([0, 1, 2, 3])

# %%
plt.barh(ind, counts, width, color=colors)
plt.barh(ind + width, counts2, width, color=colors2)

plt.yticks(ind + width / 2, fruits)
plt.show()

# %%
# data1, data2 이용
plt.scatter(data1, data2)
plt.show()

# %%
area = 30
colors = np.random.rand(1000)

plt.scatter(data1, data2, s=area, c=colors, alpha=0.5)
plt.show()

# %%
data3 = np.random.normal(1, 50, 1000)

# %%
plt.scatter(data1, data2, s=data3, c=data3, alpha=0.6, cmap='hsv')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/matplotlib/collections.py:1008: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
import seaborn as sns
iris = sns.load_dataset("iris")
g = sns.PairGrid(iris, hue="species")
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)
g.add_legend()
plt.show()

# %%
data_con = [[3, 4, 5], [4, 5, 3], [3, 4, 3]]

plt.imshow(data_con)
plt.imshow(data_con, cmap='autumn')
plt.colorbar()
plt.show()
