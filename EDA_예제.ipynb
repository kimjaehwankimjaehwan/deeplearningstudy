# %% [markdown]
# <a href="https://colab.research.google.com/github/kimjaehwankimjaehwan/deeplearningstudy/blob/main/EDA_%EC%98%88%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/kdt_2506/data/trade_apt_api.csv', encoding='utf-8')

# %%
df.shape
# Out:
# (118, 12)

# %%
df.head()
# Out:
#      기준년월       지역명   지역코드  법정동                    아파트    거래금액     년  월   일  \
# 0  202006  서울특별시종로구  11110  신교동               신현(102동)  100000  2020  6  30
# 1  202006  서울특별시종로구  11110  사직동  광화문풍림스페이스본(101동~105동)  121500  2020  6   4
# 2  202006  서울특별시종로구  11110  사직동  광화문풍림스페이스본(101동~105동)  115000  2020  6   9
# 3  202006  서울특별시종로구  11110  사직동  광화문풍림스페이스본(101동~105동)  113000  2020  6  13
# 4  202006  서울특별시종로구  11110  사직동  광화문풍림스페이스본(101동~105동)  124000  2020  6  16
#
#    건축년도    전용면적  층
# 0  2002  134.66  5
# 1  2008  126.34  7
# 2  2008   94.28  5
# 3  2008   97.61  1
# 4  2008   94.51  5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   기준년월    118 non-null    int64
#  1   지역명     118 non-null    object
#  2   지역코드    118 non-null    int64
#  3   법정동     118 non-null    object
#  4   아파트     118 non-null    object
#  5   거래금액    118 non-null    int64
#  6   년       118 non-null    int64
#  7   월       118 non-null    int64
#  8   일       118 non-null    int64
#  9   건축년도    118 non-null    int64
#  10  전용면적    118 non-null    float64
#  11  층       118 non-null    int64
# dtypes: float64(1), int64(8), object(3)
# memory usage: 11.2+ KB

# %%
df.describe()
# Out:
#            기준년월     지역코드           거래금액       년      월           일  \
# count     118.0    118.0     118.000000   118.0  118.0  118.000000
# mean   202006.0  11110.0   90147.881356  2020.0    6.0   16.923729
# std         0.0      0.0   42873.163639     0.0    0.0    8.036409
# min    202006.0  11110.0   11200.000000  2020.0    6.0    1.000000
# 25%    202006.0  11110.0   57200.000000  2020.0    6.0   12.000000
# 50%    202006.0  11110.0   79500.000000  2020.0    6.0   17.000000
# 75%    202006.0  11110.0  120000.000000  2020.0    6.0   23.000000
# max    202006.0  11110.0  178500.000000  2020.0    6.0   30.000000
#
#               건축년도        전용면적           층
# count   118.000000  118.000000  118.000000
# mean   2001.771186   87.524769    7.635593
# std      10.838686   36.626369    4.649539
# min    1966.000000   12.780000    1.000000
# 25%    1993.000000   59.983250    4.000000
# 50%    2003.500000   84.847000    7.000000
# 75%    2008.000000  106.620000   10.000000
# ...

# %%
df.describe()[:2]
# Out:
#            기준년월     지역코드          거래금액       년      월           일  \
# count     118.0    118.0    118.000000   118.0  118.0  118.000000
# mean   202006.0  11110.0  90147.881356  2020.0    6.0   16.923729
#
#               건축년도        전용면적           층
# count   118.000000  118.000000  118.000000
# mean   2001.771186   87.524769    7.635593

# %%
# df_num = df.select_dtypes(exclude=object)
df_num = df.select_dtypes(include=np.number)
df_num.head()
# Out:
#      기준년월   지역코드    거래금액     년  월   일  건축년도    전용면적  층
# 0  202006  11110  100000  2020  6  30  2002  134.66  5
# 1  202006  11110  121500  2020  6   4  2008  126.34  7
# 2  202006  11110  115000  2020  6   9  2008   94.28  5
# 3  202006  11110  113000  2020  6  13  2008   97.61  1
# 4  202006  11110  124000  2020  6  16  2008   94.51  5

# %%
df_num.skew()
# Out:
# 기준년월    0.000000
# 지역코드    0.000000
# 거래금액    0.425389
# 년       0.000000
# 월       0.000000
# 일      -0.161751
# 건축년도   -0.895786
# 전용면적    1.047689
# 층       0.680209
# dtype: float64

# %%
df_num.skew().sort_values(ascending=False).head(1)
# Out:
# 전용면적    1.047689
# dtype: float64

# %%
df_num.skew().sort_values(ascending=False)
# Out:
# 전용면적    1.047689
# 층       0.680209
# 거래금액    0.425389
# 기준년월    0.000000
# 지역코드    0.000000
# 월       0.000000
# 년       0.000000
# 일      -0.161751
# 건축년도   -0.895786
# dtype: float64

# %%
  df_num.skew().sort_values(ascending=False)[0]
# Out:
# <ipython-input-14-1785571003>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df_num.skew().sort_values(ascending=False)[0]
# np.float64(1.0476886131451)

# %%
df_num.skew().sort_values(ascending=False).index
# Out:
# Index(['전용면적', '층', '거래금액', '기준년월', '지역코드', '월', '년', '일', '건축년도'], dtype='object')

# %%
df_num.skew().sort_values(ascending=False).index[0], df_num.skew().sort_values(ascending=False)[0]
# Out:
# <ipython-input-16-3874263488>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df_num.skew().sort_values(ascending=False).index[0], df_num.skew().sort_values(ascending=False)[0]
# ('전용면적', np.float64(1.0476886131451))

# %%
df_kurt = df_num.kurt().sort_values(ascending=False)
df_kurt
# Out:
# 전용면적    2.186925
# 건축년도    1.632411
# 기준년월    0.000000
# 지역코드    0.000000
# 년       0.000000
# 월       0.000000
# 층      -0.206307
# 거래금액   -0.730072
# 일      -0.734121
# dtype: float64

# %%
df_kurt.index[0], df_kurt[0], df_num['전용면적'].var(), df_num['전용면적'].std()
# Out:
# <ipython-input-18-4279581070>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df_kurt.index[0], df_kurt[0], df_num['전용면적'].var(), df_num['전용면적'].std()
# ('전용면적', np.float64(2.18692536998014), 1341.4909063040182, 36.6263690024553)

# %%
print("column {}의 첨도가 {:.2f}로 가장 높고, 분산은 {:.2f}, 표준편차는 {:.2f}입니다.".format(df_kurt.index[0], df_kurt[0], df_num['전용면적'].var(), df_num['전용면적'].std()))
# Out:
# column 전용면적의 첨도가 2.19로 가장 높고, 분산은 1341.49, 표준편차는 36.63입니다.
# <ipython-input-19-1352519438>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print("column {}의 첨도가 {:.2f}로 가장 높고, 분산은 {:.2f}, 표준편차는 {:.2f}입니다.".format(df_kurt.index[0], df_kurt[0], df_num['전용면적'].var(), df_num['전용면적'].std()))

# %%
df
# Out:
#        기준년월       지역명   지역코드  법정동                    아파트    거래금액     년  월   일  \
# 0    202006  서울특별시종로구  11110  신교동               신현(102동)  100000  2020  6  30
# 1    202006  서울특별시종로구  11110  사직동  광화문풍림스페이스본(101동~105동)  121500  2020  6   4
# 2    202006  서울특별시종로구  11110  사직동  광화문풍림스페이스본(101동~105동)  115000  2020  6   9
# 3    202006  서울특별시종로구  11110  사직동  광화문풍림스페이스본(101동~105동)  113000  2020  6  13
# 4    202006  서울특별시종로구  11110  사직동  광화문풍림스페이스본(101동~105동)  124000  2020  6  16
# ..      ...       ...    ...  ...                    ...     ...   ... ..  ..
# 113  202006  서울특별시종로구  11110  무악동                     현대  100990  2020  6  23
# 114  202006  서울특별시종로구  11110  무악동                인왕산아이파크   97000  2020  6  23
# 115  202006  서울특별시종로구  11110  무악동                인왕산아이파크  120000  2020  6  27
# 116  202006  서울특별시종로구  11110  무악동                     현대   74990  2020  6  27
# 117  202006  서울특별시종로구  11110  무악동                     현대  110900  2020  6  30
#
#      건축년도     전용면적   층
# ...

# %%
df_dong = df.drop(['지역명', '아파트'], axis=1)
df_dong
# Out:
#        기준년월   지역코드  법정동    거래금액     년  월   일  건축년도     전용면적   층
# 0    202006  11110  신교동  100000  2020  6  30  2002  134.660   5
# 1    202006  11110  사직동  121500  2020  6   4  2008  126.340   7
# 2    202006  11110  사직동  115000  2020  6   9  2008   94.280   5
# 3    202006  11110  사직동  113000  2020  6  13  2008   97.610   1
# 4    202006  11110  사직동  124000  2020  6  16  2008   94.510   5
# ..      ...    ...  ...     ...   ... ..  ..   ...      ...  ..
# 113  202006  11110  무악동  100990  2020  6  23  2000   84.920  13
# 114  202006  11110  무악동   97000  2020  6  23  2008   84.858   2
# 115  202006  11110  무악동  120000  2020  6  27  2008   84.858   9
# 116  202006  11110  무악동   74990  2020  6  27  2000   60.000   6
# 117  202006  11110  무악동  110900  2020  6  30  2000  114.900   4
#
# [118 rows x 10 columns]

# %%
df_dong.groupby('법정동').mean()['거래금액']
# Out:
# 법정동
# 교북동      62000.000000
# 구기동      40000.000000
# 내수동     152642.857143
# 당주동      79000.000000
# 명륜2가     89700.000000
# 무악동     103446.875000
# 사직동     125166.666667
# 숭인동      54316.666667
# 신교동     100000.000000
# 익선동      41500.000000
# 인의동      88400.000000
# 창신동      57043.589744
# 평동      151500.000000
# 평창동      78985.714286
# 홍파동     161500.000000
# Name: 거래금액, dtype: float64

# %%
pd.options.display.float_format = '{:.2f}'.format
df_dong.groupby('법정동').mean()['거래금액']
# Out:
# 법정동
# 교북동     62000.00
# 구기동     40000.00
# 내수동    152642.86
# 당주동     79000.00
# 명륜2가    89700.00
# 무악동    103446.88
# 사직동    125166.67
# 숭인동     54316.67
# 신교동    100000.00
# 익선동     41500.00
# 인의동     88400.00
# 창신동     57043.59
# 평동     151500.00
# 평창동     78985.71
# 홍파동    161500.00
# Name: 거래금액, dtype: float64

# %%
df_day = df.groupby('일').sum()['거래금액']

# %%
df_day
# Out:
# 일
# 1      286500
# 2      139000
# 3      208500
# 4      289000
# 5      300500
# 6       49500
# 7      135000
# 8      217700
# 9      345000
# 10      85100
# 12     423750
# 13     626800
# 14     114000
# 15     365300
# 16    1134530
# 17     496500
# 18     650690
# 19     157000
# 20     811300
# 22     564000
# 23     306990
# 24     386600
# 25     160500
# 26     380000
# 27     822490
# 29     266000
# 30     915200
# Name: 거래금액, dtype: int64

# %%
df_grp = df_dong.groupby(['일', '법정동']).sum()
df_grp
# Out:
#           기준년월   지역코드    거래금액     년   월  건축년도   전용면적   층
# 일  법정동
# 1  내수동  202006  11110  140000  2020   6  2004 124.17   4
#    숭인동  202006  11110   71200  2020   6  2008  59.92  10
#    창신동  202006  11110   75300  2020   6  1992 106.62  13
# 2  익선동  202006  11110   36000  2020   6  2003  48.54   9
#    창신동  404012  22220  103000  4040  12  3986 134.57   7
# ...        ...    ...     ...   ...  ..   ...    ...  ..
# 30 숭인동  202006  11110   74900  2020   6  2008  59.92   9
#    신교동  202006  11110  100000  2020   6  2002 134.66   5
#    인의동  404012  22220  210000  4040  12  4012 268.25  34
#    창신동  404012  22220  114900  4040  12  3984 109.40   6
#    홍파동  404012  22220  304500  4040  12  4034 144.76  26
#
# [88 rows x 8 columns]

# %%
df['법정동'].unique()
# Out:
# array(['신교동', '사직동', '당주동', '내수동', '익선동', '인의동', '명륜2가', '창신동', '숭인동',
#        '평동', '홍파동', '교북동', '구기동', '평창동', '무악동'], dtype=object)

# %%
df_grp = df.groupby(['일', '법정동']).sum()
df_grp
# Out:
#           기준년월               지역명   지역코드                   아파트    거래금액     년  \
# 일  법정동
# 1  내수동  202006          서울특별시종로구  11110             경희궁의아침2단지  140000  2020
#    숭인동  202006          서울특별시종로구  11110                종로센트레빌   71200  2020
#    창신동  202006          서울특별시종로구  11110                 창신쌍용1   75300  2020
# 2  익선동  202006          서울특별시종로구  11110                현대뜨레비앙   36000  2020
#    창신동  404012  서울특별시종로구서울특별시종로구  22220            창신쌍용2창신쌍용2  103000  4040
# ...        ...               ...    ...                   ...     ...   ...
# 30 숭인동  202006          서울특별시종로구  11110                종로센트레빌   74900  2020
#    신교동  202006          서울특별시종로구  11110              신현(102동)  100000  2020
#    인의동  404012  서울특별시종로구서울특별시종로구  22220        효성쥬얼리시티효성쥬얼리시티  210000  4040
#    창신동  404012  서울특별시종로구서울특별시종로구  22220            창신쌍용1창신쌍용1  114900  4040
#    홍파동  404012  서울특별시종로구서울특별시종로구  22220  경희궁자이(2단지)경희궁자이(2단지)  304500  4040
#
#          월  건축년도   전용면적   층
# 일  법정동
# ...

# %%
df_grp = df.groupby(['일', '법정동'], as_index=False).sum()
df_grp
# Out:
#      일  법정동    기준년월               지역명   지역코드                   아파트    거래금액  \
# 0    1  내수동  202006          서울특별시종로구  11110             경희궁의아침2단지  140000
# 1    1  숭인동  202006          서울특별시종로구  11110                종로센트레빌   71200
# 2    1  창신동  202006          서울특별시종로구  11110                 창신쌍용1   75300
# 3    2  익선동  202006          서울특별시종로구  11110                현대뜨레비앙   36000
# 4    2  창신동  404012  서울특별시종로구서울특별시종로구  22220            창신쌍용2창신쌍용2  103000
# ..  ..  ...     ...               ...    ...                   ...     ...
# 83  30  숭인동  202006          서울특별시종로구  11110                종로센트레빌   74900
# 84  30  신교동  202006          서울특별시종로구  11110              신현(102동)  100000
# 85  30  인의동  404012  서울특별시종로구서울특별시종로구  22220        효성쥬얼리시티효성쥬얼리시티  210000
# 86  30  창신동  404012  서울특별시종로구서울특별시종로구  22220            창신쌍용1창신쌍용1  114900
# 87  30  홍파동  404012  서울특별시종로구서울특별시종로구  22220  경희궁자이(2단지)경희궁자이(2단지)  304500
#
#        년   월  건축년도   전용면적   층
# 0   2020   6  2004 124.17   4
# ...

# %%
df_grp['평단가'] = (df_grp['거래금액'] / df_grp['전용면적'])* 3.3
df_grp.sort_values('평단가', ascending=False).head()
# Out:
#      일  법정동    기준년월               지역명   지역코드                   아파트    거래금액  \
# 6    3   평동  202006          서울특별시종로구  11110            경희궁자이(3단지)  141500
# 81  29   평동  202006          서울특별시종로구  11110            경희궁자이(3단지)  140000
# 60  20   평동  202006          서울특별시종로구  11110            경희궁자이(3단지)  137000
# 87  30  홍파동  404012  서울특별시종로구서울특별시종로구  22220  경희궁자이(2단지)경희궁자이(2단지)  304500
# 53  18  홍파동  202006          서울특별시종로구  11110            경희궁자이(2단지)  174000
#
#        년   월  건축년도   전용면적   층     평단가
# 6   2020   6  2017  59.85   7 7801.35
# 81  2020   6  2017  59.85   5 7718.65
# 60  2020   6  2017  59.85   3 7553.25
# 87  4040  12  4034 144.76  26 6941.39
# 53  2020   6  2017  84.84  16 6768.35

# %%
df_corr = df_num.corr()['거래금액'].sort_values(ascending=False).dropna()
df_corr
# Out:
# 거래금액   1.00
# 건축년도   0.56
# 전용면적   0.55
# 일      0.21
# 층      0.19
# Name: 거래금액, dtype: float64
