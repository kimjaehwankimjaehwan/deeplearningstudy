# %% [markdown]
# <a href="https://colab.research.google.com/github/kimjaehwankimjaehwan/deeplearningstudy/blob/main/%EA%B8%B0%EB%B3%B8%EC%B0%A8%ED%8A%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot([1, 3, 2, 4])
plt.show()

# %%
plt.plot([1, 3, 2, 4])
plt.plot([0, 4, 1, 3])
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# 시스템 기본 폰트 설정 (DejaVu Sans)
mpl.rc('font', family='DejaVu Sans')
plt.rcParams['axes.unicode_minus'] = False

# %%
plt.plot([1, 3, 2, 4])
plt.plot([0, 4, 1, 3])
plt.title('예제차트1')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53944 (\N{HANGUL SYLLABLE TEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.plot([1, 3, 2, 4])
plt.plot([0, 4, 1, 3])
plt.title('example chart #1', loc='left', pad=30, fontsize=30, fontweight='bold', color='red')
plt.show()

# %%
plt.plot([1, 3, 2, 4])
plt.plot([0, 4, 1, 3])
plt.title('example chart #1', loc='left', pad=20, fontsize=30, fontweight='bold', color='red')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %%
plt.plot([1, 3, 2, 4])
plt.plot([0, 4, 1, 3])
plt.title('example chart #1', loc='left', pad=20, fontsize=30, color='red')
plt.xlabel('x-axis', loc='right', labelpad=15, fontsize=10, color='blue')
plt.ylabel('y-axis', loc='top', labelpad=15, fontsize=10, color='blue')
plt.show()

# %%
plt.plot([1, 3, 2, 4])
plt.plot([0, 4, 1, 3])
plt.title('example chart #1', loc='left', pad=20, fontsize=30, color='red')
plt.xlabel('x-axis', loc='right', labelpad=15, fontsize=10, color='blue')
plt.plot([1, 3, 2, 4])
plt.plot([0, 4, 1, 3])
plt.title('example chart #1', loc='left', pad=20, fontsize=30, color='red')
plt.xlabel('x-axis', loc='right', labelpad=15, fontsize=10, color='blue')
plt.ylabel('y-axis', loc='top', labelpad=15, fontsize=10, color='blue')

plt.xticks([0, 1, 2, 3], labels = ['1Q', '2Q', '3Q', '4Q'])
plt.yticks(np.arange(5) , labels = ['0', '1k', '2k', '3k', '4k' ])
plt.show()

# %%
plt.plot([1, 3, 2, 4])
plt.plot([0, 4, 1, 3])
plt.title('example chart #1', loc='left', pad=20, fontsize=30, color='red')
plt.xlabel('x-axis', loc='right', labelpad=15, fontsize=10, color='blue')
plt.ylabel('y-axis', loc='top', labelpad=15, fontsize=10, color='blue')

plt.xticks([0, 1, 2, 3], labels=['1Q', '2Q', '3Q', '4Q'])
plt.yticks(np.arange(5), labels=['0', '1k', '2k', '3k', '4k'])
plt.show()

# %%
plt.plot([1, 3, 2, 4])
plt.plot([0, 4, 1, 3])
plt.title('example chart #1', loc='left', pad=20, fontsize=30, color='red')
plt.xlabel('x-axis', loc='right', labelpad=15, fontsize=10, color='blue')
plt.ylabel('y-axis', loc='top', labelpad=15, fontsize=10, color='blue')
plt.xticks([0, 1, 2, 3], labels=['1Q', '2Q', '3Q', '4Q'])
plt.yticks(np.arange(5), labels=['0', '1k', '2k', '3k', '4k'])

plt.tick_params(axis='x', direction='inout', length=20, pad=20, width=5, color='red', labelsize=20, labelcolor='Orange', labelrotation=90)
plt.show()

# %%
plt.plot([1, 3, 2, 4])
plt.plot([0, 4, 1, 3])
plt.title('example chart #1', loc='left', pad=20, fontsize=30, color='red')
plt.xlabel('x-axis', loc='right', labelpad=15, fontsize=10, color='blue')
plt.ylabel('y-axis', loc='top', labelpad=15, fontsize=10, color='blue')
plt.xticks([0, 1, 2, 3], labels=['1Q', '2Q', '3Q', '4Q'])
plt.yticks(np.arange(5), labels=['0', '1k', '2k', '3k', '4k'])
plt.tick_params(axis='x', direction='inout', length=20, pad=20, width=5, color='red', labelsize=20, labelcolor='Orange', labelrotation=90)

plt.legend(labels=['count', 'client'])
plt.show()

# %%
plt.plot([1, 3, 2, 4])
plt.plot([0, 4, 1, 3])
plt.title('example chart #1', loc='left', pad=20, fontsize=30, color='red')
plt.xlabel('x-axis', loc='right', labelpad=15, fontsize=10, color='blue')
plt.ylabel('y-axis', loc='top', labelpad=15, fontsize=10, color='blue')
plt.xticks([0, 1, 2, 3], labels=['1Q', '2Q', '3Q', '4Q'])
plt.yticks(np.arange(5), labels=['0', '1k', '2k', '3k', '4k'])
plt.tick_params(axis='x', direction='inout', length=20, pad=20, width=5, color='red', labelsize=20, labelcolor='Orange', labelrotation=90)

plt.legend(labels=['count', 'client'], loc='best', ncols=2, fontsize=10, frameon=True, shadow=True, facecolor='#EEEEEE', labelcolor='Green')
plt.show()

# %%
plt.plot([1, 3, 2, 4])
plt.plot([0, 4, 1, 3])
plt.title('example chart #1', loc='left', pad=20, fontsize=30, color='red')
plt.xlabel('x-axis', loc='right', labelpad=15, fontsize=10, color='blue')
plt.ylabel('y-axis', loc='top', labelpad=15, fontsize=10, color='blue')
plt.xticks([0, 1, 2, 3], labels=['1Q', '2Q', '3Q', '4Q'])
plt.yticks(np.arange(5), labels=['0', '1k', '2k', '3k', '4k'])
plt.tick_params(axis='x', direction='inout', length=20, pad=20, width=5, color='red', labelsize=20, labelcolor='Orange', labelrotation=90)
plt.legend(labels=['count', 'client'], loc='best', ncols=2, fontsize=20, frameon=True, shadow=True, facecolor='#EEEEEE', labelcolor='Pink')
# loc : best, center, right, upper right, upper left, lower left, lower right, center left, center right, lower center, upper center

plt.xlim(1, 3)
plt.ylim(-1, 5)
plt.show()

# %%
plt.plot([1, 3, 2, 4])
plt.plot([0, 4, 1, 3])
plt.title('example chart #1', loc='left', pad=20, fontsize=30, color='red')
plt.xlabel('x-axis', loc='right', labelpad=15, fontsize=10, color='blue')
plt.ylabel('y-axis', loc='top', labelpad=15, fontsize=10, color='blue')
plt.xticks([0, 1, 2, 3], labels=['1Q', '2Q', '3Q', '4Q'])
plt.yticks(np.arange(5), labels=['0', '1k', '2k', '3k', '4k'])
plt.tick_params(axis='x', direction='inout', length=20, pad=20, width=5, color='red', labelsize=20, labelcolor='Orange', labelrotation=90)
plt.legend(labels=['count', 'client'], loc='best', ncols=2, fontsize=20, frameon=True, shadow=True, facecolor='#EEEEEE', labelcolor='Green')

plt.axis([1, 3, -1, 5])
plt.show()

# %%
plt.plot([1, 3, 2, 4])
plt.plot([0, 4, 1, 3])
plt.title('example chart #1', loc='left', pad=20, fontsize=30, color='red')
plt.xlabel('x-axis', loc='right', labelpad=15, fontsize=10, color='blue')
plt.ylabel('y-axis', loc='top', labelpad=15, fontsize=10, color='blue')
plt.xticks([0, 1, 2, 3], labels=['1Q', '2Q', '3Q', '4Q'])
plt.yticks(np.arange(5), labels=['0', '1k', '2k', '3k', '4k'])
plt.tick_params(axis='x', direction='inout', length=20, pad=20, width=5, color='red', labelsize=20, labelcolor='Orange', labelrotation=90)
plt.legend(labels=['count', 'client'], loc='best', ncols=2, fontsize=20, frameon=True, shadow=True, facecolor='#EEEEEE', labelcolor='Green')

plt.axis('scaled')
# plt.axis('off')   on, off, equal, scaled, tight, auto, image, square
plt.show()

# %%
plt.plot([1, 3, 2, 4], 'b-.', label='count', linewidth=10, dash_capstyle='projecting')
# dash_capstyle : 'butt', 'projecting', 'round'
plt.plot([0, 4, 1, 3], linestyle='solid', color='red', label='client')
# '-' : Solid, '--' : Dashed,  '-.' : Dash-dot, ':' : Dotted

plt.title('example chart #1', loc='left', pad=20, fontsize=30, color='red')
plt.xlabel('x-axis', loc='right', labelpad=15, fontsize=10, color='blue')
plt.ylabel('y-axis', loc='top', labelpad=15, fontsize=10, color='blue')
plt.xticks([0, 1, 2, 3], labels=['1Q', '2Q', '3Q', '4Q'])
plt.yticks(np.arange(5), labels=['0', '1k', '2k', '3k', '4k'])
plt.tick_params(axis='x', direction='inout', length=20, pad=20, width=5, color='red', labelsize=20, labelcolor='Orange', labelrotation=90)
# plt.legend(labels=['count', 'client'], loc='best', ncols=2, fontsize=20, frameon=True, shadow=True, facecolor='#EEEEEE', labelcolor='Green')
plt.legend(loc='best', ncols=2, fontsize=20, frameon=True, shadow=True, facecolor='#EEEEEE', labelcolor='Green')
plt.axis('auto')
plt.show()

# %%
plt.plot([1, 3, 2, 4], 'b--', label='count', linewidth=10, dash_capstyle='round')
plt.plot([0, 4, 1, 3], marker='s', linestyle='solid', color='red', label='client', markersize=10, markerfacecolor='orange', markeredgecolor='orange')
# plt.plot([0, 4, 1, 3], 'o', linestyle='solid', color='red', label='client', markersize=10, markerfacecolor='orange', markeredgecolor='orange')

plt.title('example chart #1', loc='left', pad=20, fontsize=30, color='red')
plt.xlabel('x-axis', loc='right', labelpad=15, fontsize=10, color='blue')
plt.ylabel('y-axis', loc='top', labelpad=15, fontsize=10, color='blue')
plt.xticks([0, 1, 2, 3], labels=['1Q', '2Q', '3Q', '4Q'])
plt.yticks(np.arange(5), labels=['0', '1k', '2k', '3k', '4k'])
plt.tick_params(axis='x', direction='inout', length=20, pad=20, width=5, color='red', labelsize=20, labelcolor='Orange', labelrotation=90)
plt.legend(loc='best', ncols=2, fontsize=20, frameon=True, shadow=True, facecolor='#EEEEEE', labelcolor='Green')
plt.axis('auto')
plt.show()
