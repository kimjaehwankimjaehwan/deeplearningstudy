# %% [markdown]
# <a href="https://colab.research.google.com/github/kimjaehwankimjaehwan/deeplearningstudy/blob/main/08_%EC%A7%80%EB%8F%84_%EC%8B%9C%EA%B0%81%ED%99%94%EC%98%88%EC%A0%9C_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium
import pandas as pd

# %% [markdown]
# 아파트 실거래 데이터 적용 #1

# %%
df = pd.read_csv('/content/drive/MyDrive/data/trade_apt_api_2023_address.txt', sep='\t')
df['거래금액'] = df['거래금액'].str.replace(',', '').str.replace(' ', '').astype(int)
df['주소'] = '서울시 ' + df['지역명'] + ' ' + df['법정동'] + ' ' + df['지번']
df_jr = df.loc[(df['지역명']=='종로구')&(df['기준년월']>=202301),:]
df_jr_grp = df_jr.groupby('주소').mean()
df_jr_grp
# Out:
# <ipython-input-2-dcc8e3595073>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_jr_grp = df_jr.groupby('주소').mean()
#                               기준년월     지역코드           거래금액       년         월  \
# 주소
# 서울시 종로구  구기동 125-5   202306.000000  11110.0   56000.000000  2023.0  6.000000
# 서울시 종로구  내수동 72      202304.000000  11110.0  220000.000000  2023.0  4.000000
# 서울시 종로구  내수동 73      202304.500000  11110.0  184000.000000  2023.0  4.500000
# 서울시 종로구  내수동 95      202302.333333  11110.0  183333.333333  2023.0  2.333333
# 서울시 종로구  당주동 145     202306.000000  11110.0   93000.000000  2023.0  6.000000
# 서울시 종로구  동숭동 4-157   202303.000000  11110.0   41000.000000  2023.0  3.000000
# 서울시 종로구  명륜1가 19     202306.000000  11110.0   60000.000000  2023.0  6.000000
# ...

# %% [markdown]
# 위도, 경도 가져오는 함수 만들기 : 더 정확한 위도, 경도는 google, naver, kakao등의 지도 API를 이용

# %% [markdown]
# 구한 위도, 경도를 이용하여 지도 시각화

# %%
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
